# %%
# !pip install tensorflow-gpu==1.15.0
# Out:
# Collecting tensorflow-gpu==1.15.0
#   Downloading https://files.pythonhosted.org/packages/a5/ad/933140e74973fb917a194ab814785e7c23680ca5dee6d663a509fe9579b6/tensorflow_gpu-1.15.0-cp36-cp36m-manylinux2010_x86_64.whl (411.5MB)
#      |████████████████████████████████| 411.5MB 36kB/s
# Requirement already satisfied: gast==0.2.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.0) (0.2.2)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.0) (1.1.0)
# Requirement already satisfied: tensorboard<1.16.0,>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.0) (1.15.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.0) (1.1.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.0) (0.33.6)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.0) (1.0.8)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.0) (3.10.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.0) (0.1.8)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.0) (3.1.0)
# Requirement already satisfied: tensorflow-estimator==1.15.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.0) (1.15.1)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.0) (1.11.2)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.0) (1.15.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.0) (1.12.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.0) (1.17.4)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.0) (0.8.1)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.0) (0.8.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.0) (0.16.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.0) (41.6.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.0) (3.1.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow-gpu==1.15.0) (2.8.0)
# Installing collected packages: tensorflow-gpu
# Successfully installed tensorflow-gpu-1.15.0

# %% [markdown]
# The data is based on 1990 census data from California. This data is at the city block level, so these features reflect the total number of rooms in that block, or the total number of people who live on that block, respectively.

# %% [markdown]
# **Learning Objectives:**
#   * Use the `DNNRegressor` class in TensorFlow to predict median housing price

# %%
import math
import shutil
import numpy as np
import pandas as pd
import tensorflow as tf

print(tf.__version__)
tf.logging.set_verbosity(tf.logging.INFO)
pd.options.display.max_rows = 10
pd.options.display.float_format = '{:.1f}'.format
# Out:
# 1.15.0

# %%
df = pd.read_csv("https://storage.googleapis.com/ml_universities/california_housing_train.csv", sep=",")

# %%
df.head()
# Out:
#    longitude  latitude  ...  median_income  median_house_value
# 0     -114.3      34.2  ...            1.5             66900.0
# 1     -114.5      34.4  ...            1.8             80100.0
# 2     -114.6      33.7  ...            1.7             85700.0
# 3     -114.6      33.6  ...            3.2             73400.0
# 4     -114.6      33.6  ...            1.9             65500.0
#
# [5 rows x 9 columns]

# %%
df.describe()
# Out:
#        longitude  latitude  ...  median_income  median_house_value
# count    17000.0   17000.0  ...        17000.0             17000.0
# mean      -119.6      35.6  ...            3.9            207300.9
# std          2.0       2.1  ...            1.9            115983.8
# min       -124.3      32.5  ...            0.5             14999.0
# 25%       -121.8      33.9  ...            2.6            119400.0
# 50%       -118.5      34.2  ...            3.5            180400.0
# 75%       -118.0      37.7  ...            4.8            265000.0
# max       -114.3      42.0  ...           15.0            500001.0
#
# [8 rows x 9 columns]

# %% [markdown]
# This data is at the city block level, so these features reflect the total number of rooms in that block, or the total number of people who live on that block, respectively.  Let's create a different, more appropriate feature.  Because we are predicing the price of a single house, we should try to make all our features correspond to a single house as well

# %%
df['num_rooms'] = df['total_rooms'] / df['households']
df['num_bedrooms'] = df['total_bedrooms'] / df['households']
df['persons_per_house'] = df['population'] / df['households']
df.describe()
# Out:
#        longitude  latitude  ...  num_bedrooms  persons_per_house
# count    17000.0   17000.0  ...       17000.0            17000.0
# mean      -119.6      35.6  ...           1.1                3.0
# std          2.0       2.1  ...           0.5                4.0
# min       -124.3      32.5  ...           0.3                0.7
# 25%       -121.8      33.9  ...           1.0                2.4
# 50%       -118.5      34.2  ...           1.0                2.8
# 75%       -118.0      37.7  ...           1.1                3.3
# max       -114.3      42.0  ...          34.1              502.5
#
# [8 rows x 12 columns]

# %% [markdown]
# ## Build a neural network model
#
# In this exercise, we'll be trying to predict `median_house_value`. It will be our label (sometimes also called a target). We'll use the remaining columns as our input features.
#
# To train our model, we'll first use the [LinearRegressor](https://www.tensorflow.org/api_docs/python/tf/contrib/learn/LinearRegressor) interface. Then, we'll change to DNNRegressor

# %%
featcols = {
  colname : tf.feature_column.numeric_column(colname) \
    for colname in 'housing_median_age,median_income,num_rooms,num_bedrooms,persons_per_house'.split(',')
}
# Bucketize lat, lon so it's not so high-res; California is mostly N-S, so more lats than lons
featcols['longitude'] = tf.feature_column.bucketized_column(tf.feature_column.numeric_column('longitude'),
                                                   np.linspace(-124.3, -114.3, 5).tolist())
featcols['latitude'] = tf.feature_column.bucketized_column(tf.feature_column.numeric_column('latitude'),
                                                  np.linspace(32.5, 42, 10).tolist())

# %%
featcols.keys()
# Out:
# dict_keys(['housing_median_age', 'median_income', 'num_rooms', 'num_bedrooms', 'persons_per_house', 'longitude', 'latitude'])

# %%
# Split into train and eval
msk = np.random.rand(len(df)) < 0.8
traindf = df[msk]
evaldf = df[~msk]

SCALE = 100000
BATCH_SIZE= 100
OUTDIR = './housing_trained'
train_input_fn = tf.estimator.inputs.pandas_input_fn(x = traindf[list(featcols.keys())],
                                                    y = traindf["median_house_value"] / SCALE,
                                                    num_epochs = None,
                                                    batch_size = BATCH_SIZE,
                                                    shuffle = True)
eval_input_fn = tf.estimator.inputs.pandas_input_fn(x = evaldf[list(featcols.keys())],
                                                    y = evaldf["median_house_value"] / SCALE,  # note the scaling
                                                    num_epochs = 1, 
                                                    batch_size = len(evaldf), 
                                                    shuffle=False)

# %%
# Linear Regressor
def train_and_evaluate(output_dir, num_train_steps):
  myopt = tf.train.FtrlOptimizer(learning_rate = 0.01) # note the learning rate
  estimator = tf.estimator.LinearRegressor(
                       model_dir = output_dir, 
                       feature_columns = featcols.values(),
                       optimizer = myopt)
  
  #Add rmse evaluation metric
  def rmse(labels, predictions):
    pred_values = tf.cast(predictions['predictions'],tf.float64)
    return {'rmse': tf.metrics.root_mean_squared_error(labels*SCALE, pred_values*SCALE)}
  estimator = tf.contrib.estimator.add_metrics(estimator,rmse)
  
  train_spec=tf.estimator.TrainSpec(
                       input_fn = train_input_fn,
                       max_steps = num_train_steps)
  eval_spec=tf.estimator.EvalSpec(
                       input_fn = eval_input_fn,
                       steps = None,
                       start_delay_secs = 1, # start evaluating after N seconds
                       throttle_secs = 10,  # evaluate every N seconds
                       )
  tf.estimator.train_and_evaluate(estimator, train_spec, eval_spec)

# Run training    
shutil.rmtree(OUTDIR, ignore_errors = True) # start fresh each time
train_and_evaluate(OUTDIR, num_train_steps = (100 * len(traindf)) / BATCH_SIZE)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': './housing_trained', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f40d7d22be0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Using config: {'_model_dir': './housing_trained', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f40d7d22358>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./housing_trained/model.ckpt.
# INFO:tensorflow:loss = 629.2108, step = 1
# INFO:tensorflow:global_step/sec: 226.025
# INFO:tensorflow:loss = 85.45376, step = 101 (0.445 sec)
# INFO:tensorflow:global_step/sec: 297.797
# INFO:tensorflow:loss = 65.5567, step = 201 (0.335 sec)
# INFO:tensorflow:global_step/sec: 290.882
# INFO:tensorflow:loss = 209.22487, step = 301 (0.344 sec)
# INFO:tensorflow:global_step/sec: 299.516
# INFO:tensorflow:loss = 51.524437, step = 401 (0.336 sec)
# INFO:tensorflow:global_step/sec: 294.496
# INFO:tensorflow:loss = 99.794464, step = 501 (0.346 sec)
# INFO:tensorflow:global_step/sec: 301.631
# INFO:tensorflow:loss = 27.856993, step = 601 (0.327 sec)
# INFO:tensorflow:global_step/sec: 299.234
# INFO:tensorflow:loss = 97.366776, step = 701 (0.335 sec)
# INFO:tensorflow:global_step/sec: 292.905
# INFO:tensorflow:loss = 88.02621, step = 801 (0.338 sec)
# INFO:tensorflow:global_step/sec: 285.206
# INFO:tensorflow:loss = 74.21839, step = 901 (0.355 sec)
# INFO:tensorflow:global_step/sec: 167.882
# INFO:tensorflow:loss = 33.298656, step = 1001 (0.593 sec)
# INFO:tensorflow:global_step/sec: 304.812
# INFO:tensorflow:loss = 54.38159, step = 1101 (0.326 sec)
# INFO:tensorflow:global_step/sec: 293.305
# INFO:tensorflow:loss = 104.6771, step = 1201 (0.342 sec)
# INFO:tensorflow:global_step/sec: 279.296
# INFO:tensorflow:loss = 69.68184, step = 1301 (0.357 sec)
# INFO:tensorflow:global_step/sec: 286.732
# INFO:tensorflow:loss = 60.78098, step = 1401 (0.349 sec)
# INFO:tensorflow:global_step/sec: 300.784
# INFO:tensorflow:loss = 48.490585, step = 1501 (0.337 sec)
# INFO:tensorflow:global_step/sec: 280.724
# INFO:tensorflow:loss = 33.576263, step = 1601 (0.352 sec)
# INFO:tensorflow:global_step/sec: 289.216
# INFO:tensorflow:loss = 51.302364, step = 1701 (0.351 sec)
# INFO:tensorflow:global_step/sec: 282.867
# INFO:tensorflow:loss = 111.76302, step = 1801 (0.350 sec)
# INFO:tensorflow:global_step/sec: 278.239
# INFO:tensorflow:loss = 29.96921, step = 1901 (0.358 sec)
# INFO:tensorflow:global_step/sec: 292.425
# INFO:tensorflow:loss = 49.303787, step = 2001 (0.343 sec)
# INFO:tensorflow:global_step/sec: 294.971
# INFO:tensorflow:loss = 26.382872, step = 2101 (0.339 sec)
# INFO:tensorflow:global_step/sec: 284.275
# INFO:tensorflow:loss = 79.11102, step = 2201 (0.350 sec)
# INFO:tensorflow:global_step/sec: 297.68
# INFO:tensorflow:loss = 50.071983, step = 2301 (0.336 sec)
# INFO:tensorflow:global_step/sec: 297.104
# INFO:tensorflow:loss = 132.54922, step = 2401 (0.337 sec)
# INFO:tensorflow:global_step/sec: 284.739
# INFO:tensorflow:loss = 56.20579, step = 2501 (0.356 sec)
# INFO:tensorflow:global_step/sec: 281.01
# INFO:tensorflow:loss = 61.35439, step = 2601 (0.359 sec)
# INFO:tensorflow:global_step/sec: 300.791
# INFO:tensorflow:loss = 69.61487, step = 2701 (0.324 sec)
# INFO:tensorflow:global_step/sec: 288.525
# INFO:tensorflow:loss = 69.159615, step = 2801 (0.354 sec)
# INFO:tensorflow:global_step/sec: 300.41
# INFO:tensorflow:loss = 51.167435, step = 2901 (0.325 sec)
# INFO:tensorflow:global_step/sec: 280.182
# INFO:tensorflow:loss = 46.218586, step = 3001 (0.358 sec)
# INFO:tensorflow:global_step/sec: 289.364
# INFO:tensorflow:loss = 45.994755, step = 3101 (0.348 sec)
# INFO:tensorflow:global_step/sec: 302.622
# INFO:tensorflow:loss = 50.814735, step = 3201 (0.326 sec)
# INFO:tensorflow:global_step/sec: 309.041
# INFO:tensorflow:loss = 52.88279, step = 3301 (0.327 sec)
# INFO:tensorflow:global_step/sec: 298.716
# INFO:tensorflow:loss = 42.70334, step = 3401 (0.339 sec)
# INFO:tensorflow:global_step/sec: 274.686
# INFO:tensorflow:loss = 37.327732, step = 3501 (0.357 sec)
# INFO:tensorflow:global_step/sec: 295.908
# INFO:tensorflow:loss = 45.488396, step = 3601 (0.343 sec)
# INFO:tensorflow:global_step/sec: 292.332
# INFO:tensorflow:loss = 135.1615, step = 3701 (0.337 sec)
# INFO:tensorflow:global_step/sec: 286.05
# INFO:tensorflow:loss = 34.920223, step = 3801 (0.356 sec)
# INFO:tensorflow:global_step/sec: 271.094
# INFO:tensorflow:loss = 101.75768, step = 3901 (0.367 sec)
# INFO:tensorflow:global_step/sec: 288.33
# INFO:tensorflow:loss = 27.268038, step = 4001 (0.342 sec)
# INFO:tensorflow:global_step/sec: 308.725
# INFO:tensorflow:loss = 80.912964, step = 4101 (0.323 sec)
# INFO:tensorflow:global_step/sec: 306.332
# INFO:tensorflow:loss = 62.528034, step = 4201 (0.327 sec)
# INFO:tensorflow:global_step/sec: 300.099
# INFO:tensorflow:loss = 61.95344, step = 4301 (0.335 sec)
# INFO:tensorflow:global_step/sec: 296.261
# INFO:tensorflow:loss = 70.4208, step = 4401 (0.336 sec)
# INFO:tensorflow:global_step/sec: 296.557
# INFO:tensorflow:loss = 39.480602, step = 4501 (0.342 sec)
# INFO:tensorflow:global_step/sec: 287.914
# INFO:tensorflow:loss = 74.69975, step = 4601 (0.343 sec)
# INFO:tensorflow:global_step/sec: 300.953
# INFO:tensorflow:loss = 60.69837, step = 4701 (0.338 sec)
# INFO:tensorflow:global_step/sec: 302.052
# INFO:tensorflow:loss = 71.80678, step = 4801 (0.329 sec)
# INFO:tensorflow:global_step/sec: 298.876
# INFO:tensorflow:loss = 57.135384, step = 4901 (0.330 sec)
# INFO:tensorflow:global_step/sec: 287.147
# INFO:tensorflow:loss = 29.78586, step = 5001 (0.348 sec)
# INFO:tensorflow:global_step/sec: 299.316
# INFO:tensorflow:loss = 51.078194, step = 5101 (0.334 sec)
# INFO:tensorflow:global_step/sec: 302.797
# INFO:tensorflow:loss = 91.87026, step = 5201 (0.331 sec)
# INFO:tensorflow:global_step/sec: 273.002
# INFO:tensorflow:loss = 34.29743, step = 5301 (0.366 sec)
# INFO:tensorflow:global_step/sec: 286.733
# INFO:tensorflow:loss = 47.737125, step = 5401 (0.351 sec)
# INFO:tensorflow:global_step/sec: 292.997
# INFO:tensorflow:loss = 18.172039, step = 5501 (0.345 sec)
# INFO:tensorflow:global_step/sec: 286.541
# INFO:tensorflow:loss = 94.55938, step = 5601 (0.344 sec)
# INFO:tensorflow:global_step/sec: 296.52
# INFO:tensorflow:loss = 53.84838, step = 5701 (0.340 sec)
# INFO:tensorflow:global_step/sec: 304.792
# INFO:tensorflow:loss = 110.990395, step = 5801 (0.326 sec)
# INFO:tensorflow:global_step/sec: 306.026
# INFO:tensorflow:loss = 23.726694, step = 5901 (0.327 sec)
# INFO:tensorflow:global_step/sec: 274.396
# INFO:tensorflow:loss = 36.324886, step = 6001 (0.370 sec)
# INFO:tensorflow:global_step/sec: 286.739
# INFO:tensorflow:loss = 48.14437, step = 6101 (0.349 sec)
# INFO:tensorflow:global_step/sec: 298.536
# INFO:tensorflow:loss = 81.428185, step = 6201 (0.331 sec)
# INFO:tensorflow:global_step/sec: 279.697
# INFO:tensorflow:loss = 67.61418, step = 6301 (0.356 sec)
# INFO:tensorflow:global_step/sec: 284.634
# INFO:tensorflow:loss = 29.747292, step = 6401 (0.352 sec)
# INFO:tensorflow:global_step/sec: 266.304
# INFO:tensorflow:loss = 42.31367, step = 6501 (0.375 sec)
# INFO:tensorflow:global_step/sec: 283.213
# INFO:tensorflow:loss = 38.70648, step = 6601 (0.353 sec)
# INFO:tensorflow:global_step/sec: 295.463
# INFO:tensorflow:loss = 67.591125, step = 6701 (0.340 sec)
# INFO:tensorflow:global_step/sec: 281.495
# INFO:tensorflow:loss = 42.0087, step = 6801 (0.359 sec)
# INFO:tensorflow:global_step/sec: 279.925
# INFO:tensorflow:loss = 40.998333, step = 6901 (0.353 sec)
# INFO:tensorflow:global_step/sec: 295.833
# INFO:tensorflow:loss = 43.048397, step = 7001 (0.340 sec)
# INFO:tensorflow:global_step/sec: 303.376
# INFO:tensorflow:loss = 146.13783, step = 7101 (0.332 sec)
# INFO:tensorflow:global_step/sec: 290.63
# INFO:tensorflow:loss = 29.235163, step = 7201 (0.339 sec)
# INFO:tensorflow:global_step/sec: 272.291
# INFO:tensorflow:loss = 162.72372, step = 7301 (0.368 sec)
# INFO:tensorflow:global_step/sec: 292.284
# INFO:tensorflow:loss = 27.528242, step = 7401 (0.343 sec)
# INFO:tensorflow:global_step/sec: 280.899
# INFO:tensorflow:loss = 67.67798, step = 7501 (0.355 sec)
# INFO:tensorflow:global_step/sec: 289.462
# INFO:tensorflow:loss = 69.922745, step = 7601 (0.345 sec)
# INFO:tensorflow:global_step/sec: 281.154
# INFO:tensorflow:loss = 42.936493, step = 7701 (0.357 sec)
# INFO:tensorflow:global_step/sec: 292.052
# INFO:tensorflow:loss = 51.40865, step = 7801 (0.345 sec)
# INFO:tensorflow:global_step/sec: 294.926
# INFO:tensorflow:loss = 30.48436, step = 7901 (0.335 sec)
# INFO:tensorflow:global_step/sec: 299.834
# INFO:tensorflow:loss = 85.55909, step = 8001 (0.335 sec)
# INFO:tensorflow:global_step/sec: 291.955
# INFO:tensorflow:loss = 42.121494, step = 8101 (0.341 sec)
# INFO:tensorflow:global_step/sec: 300.426
# INFO:tensorflow:loss = 63.091297, step = 8201 (0.333 sec)
# INFO:tensorflow:global_step/sec: 295.224
# INFO:tensorflow:loss = 49.191307, step = 8301 (0.339 sec)
# INFO:tensorflow:global_step/sec: 294.857
# INFO:tensorflow:loss = 41.13209, step = 8401 (0.340 sec)
# INFO:tensorflow:global_step/sec: 288.889
# INFO:tensorflow:loss = 58.212025, step = 8501 (0.345 sec)
# INFO:tensorflow:global_step/sec: 296.661
# INFO:tensorflow:loss = 101.84447, step = 8601 (0.341 sec)
# INFO:tensorflow:global_step/sec: 299.644
# INFO:tensorflow:loss = 37.42312, step = 8701 (0.330 sec)
# INFO:tensorflow:global_step/sec: 269.27
# INFO:tensorflow:loss = 44.549496, step = 8801 (0.371 sec)
# INFO:tensorflow:global_step/sec: 301.753
# INFO:tensorflow:loss = 18.942076, step = 8901 (0.333 sec)
# INFO:tensorflow:global_step/sec: 290.178
# INFO:tensorflow:loss = 89.83403, step = 9001 (0.343 sec)
# INFO:tensorflow:global_step/sec: 281.663
# INFO:tensorflow:loss = 46.668694, step = 9101 (0.355 sec)
# INFO:tensorflow:global_step/sec: 299.22
# INFO:tensorflow:loss = 79.16073, step = 9201 (0.334 sec)
# INFO:tensorflow:global_step/sec: 289.122
# INFO:tensorflow:loss = 29.73489, step = 9301 (0.346 sec)
# INFO:tensorflow:global_step/sec: 280.599
# INFO:tensorflow:loss = 60.908707, step = 9401 (0.362 sec)
# INFO:tensorflow:global_step/sec: 283.131
# INFO:tensorflow:loss = 93.87771, step = 9501 (0.349 sec)
# INFO:tensorflow:global_step/sec: 283.053
# INFO:tensorflow:loss = 61.600998, step = 9601 (0.351 sec)
# INFO:tensorflow:global_step/sec: 288.356
# INFO:tensorflow:loss = 54.75101, step = 9701 (0.353 sec)
# INFO:tensorflow:global_step/sec: 281.703
# INFO:tensorflow:loss = 41.1997, step = 9801 (0.349 sec)
# INFO:tensorflow:global_step/sec: 296.55
# INFO:tensorflow:loss = 28.048836, step = 9901 (0.337 sec)
# INFO:tensorflow:global_step/sec: 279.375
# INFO:tensorflow:loss = 40.405247, step = 10001 (0.367 sec)
# INFO:tensorflow:global_step/sec: 273.184
# INFO:tensorflow:loss = 64.03075, step = 10101 (0.357 sec)
# INFO:tensorflow:global_step/sec: 278.937
# INFO:tensorflow:loss = 45.559628, step = 10201 (0.363 sec)
# INFO:tensorflow:global_step/sec: 265.242
# INFO:tensorflow:loss = 25.369604, step = 10301 (0.373 sec)
# INFO:tensorflow:global_step/sec: 268.185
# INFO:tensorflow:loss = 42.14044, step = 10401 (0.372 sec)
# INFO:tensorflow:global_step/sec: 247.53
# INFO:tensorflow:loss = 162.31604, step = 10501 (0.404 sec)
# INFO:tensorflow:global_step/sec: 254.769
# INFO:tensorflow:loss = 53.260517, step = 10601 (0.395 sec)
# INFO:tensorflow:global_step/sec: 272.357
# INFO:tensorflow:loss = 109.6248, step = 10701 (0.372 sec)
# INFO:tensorflow:global_step/sec: 262.882
# INFO:tensorflow:loss = 17.263159, step = 10801 (0.378 sec)
# INFO:tensorflow:global_step/sec: 289.325
# INFO:tensorflow:loss = 98.325554, step = 10901 (0.345 sec)
# INFO:tensorflow:global_step/sec: 279.99
# INFO:tensorflow:loss = 48.70966, step = 11001 (0.353 sec)
# INFO:tensorflow:global_step/sec: 271.224
# INFO:tensorflow:loss = 75.67843, step = 11101 (0.370 sec)
# INFO:tensorflow:global_step/sec: 266.784
# INFO:tensorflow:loss = 62.65492, step = 11201 (0.380 sec)
# INFO:tensorflow:global_step/sec: 266.544
# INFO:tensorflow:loss = 39.0532, step = 11301 (0.369 sec)
# INFO:tensorflow:global_step/sec: 278.375
# INFO:tensorflow:loss = 59.897736, step = 11401 (0.357 sec)
# INFO:tensorflow:global_step/sec: 275.686
# INFO:tensorflow:loss = 62.556934, step = 11501 (0.367 sec)
# INFO:tensorflow:global_step/sec: 263.791
# INFO:tensorflow:loss = 63.99914, step = 11601 (0.377 sec)
# INFO:tensorflow:global_step/sec: 283.199
# INFO:tensorflow:loss = 50.629517, step = 11701 (0.353 sec)
# INFO:tensorflow:global_step/sec: 287.042
# INFO:tensorflow:loss = 25.704693, step = 11801 (0.348 sec)
# INFO:tensorflow:global_step/sec: 283.694
# INFO:tensorflow:loss = 64.73857, step = 11901 (0.350 sec)
# INFO:tensorflow:global_step/sec: 273.953
# INFO:tensorflow:loss = 134.3835, step = 12001 (0.365 sec)
# INFO:tensorflow:global_step/sec: 246.778
# INFO:tensorflow:loss = 48.304367, step = 12101 (0.413 sec)
# INFO:tensorflow:global_step/sec: 287.113
# INFO:tensorflow:loss = 86.86688, step = 12201 (0.341 sec)
# INFO:tensorflow:global_step/sec: 296.842
# INFO:tensorflow:loss = 18.17201, step = 12301 (0.336 sec)
# INFO:tensorflow:global_step/sec: 294.843
# INFO:tensorflow:loss = 115.20452, step = 12401 (0.339 sec)
# INFO:tensorflow:global_step/sec: 297.874
# INFO:tensorflow:loss = 70.45178, step = 12501 (0.336 sec)
# INFO:tensorflow:global_step/sec: 291.317
# INFO:tensorflow:loss = 68.10239, step = 12601 (0.343 sec)
# INFO:tensorflow:global_step/sec: 293.366
# INFO:tensorflow:loss = 33.134407, step = 12701 (0.341 sec)
# INFO:tensorflow:global_step/sec: 298.138
# INFO:tensorflow:loss = 41.6201, step = 12801 (0.335 sec)
# INFO:tensorflow:global_step/sec: 287.617
# INFO:tensorflow:loss = 79.40097, step = 12901 (0.355 sec)
# INFO:tensorflow:global_step/sec: 302.981
# INFO:tensorflow:loss = 58.645073, step = 13001 (0.328 sec)
# INFO:tensorflow:global_step/sec: 289.658
# INFO:tensorflow:loss = 51.196182, step = 13101 (0.341 sec)
# INFO:tensorflow:global_step/sec: 282.937
# INFO:tensorflow:loss = 38.18909, step = 13201 (0.352 sec)
# INFO:tensorflow:global_step/sec: 295.319
# INFO:tensorflow:loss = 33.178185, step = 13301 (0.338 sec)
# INFO:tensorflow:global_step/sec: 295.896
# INFO:tensorflow:loss = 37.494083, step = 13401 (0.339 sec)
# INFO:tensorflow:global_step/sec: 300.088
# INFO:tensorflow:loss = 66.52359, step = 13501 (0.332 sec)
# INFO:tensorflow:global_step/sec: 270.814
# INFO:tensorflow:loss = 25.38204, step = 13601 (0.374 sec)
# INFO:tensorflow:Saving checkpoints for 13601 into ./housing_trained/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-03T06:25:15Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./housing_trained/model.ckpt-13601
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-03-06:25:15
# INFO:tensorflow:Saving dict for global step 13601: average_loss = 0.5775599, global_step = 13601, label/mean = 2.0917346, loss = 1963.1261, prediction/mean = 2.0365317, rmse = 75997.34
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 13601: ./housing_trained/model.ckpt-13601
# INFO:tensorflow:Loss for final step: 25.38204.

# %%
# DNN Regressor
def train_and_evaluate(output_dir, num_train_steps):
  myopt = tf.train.FtrlOptimizer(learning_rate = 0.01) # note the learning rate
  estimator = tf.estimator.DNNRegressor(model_dir = output_dir,
                                hidden_units = [100, 50, 20],
                                feature_columns = featcols.values(),
                                optimizer = myopt,
                                dropout = 0.1)
  
  #Add rmse evaluation metric
  def rmse(labels, predictions):
    pred_values = tf.cast(predictions['predictions'],tf.float64)
    return {'rmse': tf.metrics.root_mean_squared_error(labels*SCALE, pred_values*SCALE)}
  estimator = tf.contrib.estimator.add_metrics(estimator,rmse)
  
  train_spec=tf.estimator.TrainSpec(
                       input_fn = train_input_fn,
                       max_steps = num_train_steps)
  eval_spec=tf.estimator.EvalSpec(
                       input_fn = eval_input_fn,
                       steps = None,
                       start_delay_secs = 1, # start evaluating after N seconds
                       throttle_secs = 10,  # evaluate every N seconds
                       )
  tf.estimator.train_and_evaluate(estimator, train_spec, eval_spec)

# Run training    
shutil.rmtree(OUTDIR, ignore_errors = True) # start fresh each time
tf.summary.FileWriterCache.clear() # ensure filewriter cache is clear for TensorBoard events file
train_and_evaluate(OUTDIR, num_train_steps = (100 * len(traindf)) / BATCH_SIZE)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': './housing_trained', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f40eec442e8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Using config: {'_model_dir': './housing_trained', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f40d8830278>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./housing_trained/model.ckpt.
# INFO:tensorflow:loss = 1243.5092, step = 1
# INFO:tensorflow:global_step/sec: 211.559
# INFO:tensorflow:loss = 81.63942, step = 101 (0.478 sec)
# INFO:tensorflow:global_step/sec: 248.013
# INFO:tensorflow:loss = 154.92615, step = 201 (0.402 sec)
# INFO:tensorflow:global_step/sec: 241.121
# INFO:tensorflow:loss = 33.17147, step = 301 (0.413 sec)
# INFO:tensorflow:global_step/sec: 253.096
# INFO:tensorflow:loss = 86.1845, step = 401 (0.401 sec)
# INFO:tensorflow:global_step/sec: 241.212
# INFO:tensorflow:loss = 63.09586, step = 501 (0.408 sec)
# INFO:tensorflow:global_step/sec: 237.317
# INFO:tensorflow:loss = 92.64966, step = 601 (0.423 sec)
# INFO:tensorflow:global_step/sec: 242.15
# INFO:tensorflow:loss = 52.79987, step = 701 (0.410 sec)
# INFO:tensorflow:global_step/sec: 241.003
# INFO:tensorflow:loss = 50.218277, step = 801 (0.419 sec)
# INFO:tensorflow:global_step/sec: 245.656
# INFO:tensorflow:loss = 39.690716, step = 901 (0.405 sec)
# INFO:tensorflow:global_step/sec: 249.029
# INFO:tensorflow:loss = 66.2701, step = 1001 (0.399 sec)
# INFO:tensorflow:global_step/sec: 250.626
# INFO:tensorflow:loss = 69.642075, step = 1101 (0.400 sec)
# INFO:tensorflow:global_step/sec: 261.665
# INFO:tensorflow:loss = 34.14886, step = 1201 (0.382 sec)
# INFO:tensorflow:global_step/sec: 258.028
# INFO:tensorflow:loss = 45.24083, step = 1301 (0.387 sec)
# INFO:tensorflow:global_step/sec: 239.799
# INFO:tensorflow:loss = 40.410854, step = 1401 (0.421 sec)
# INFO:tensorflow:global_step/sec: 261.006
# INFO:tensorflow:loss = 104.26152, step = 1501 (0.379 sec)
# INFO:tensorflow:global_step/sec: 258.63
# INFO:tensorflow:loss = 49.19814, step = 1601 (0.387 sec)
# INFO:tensorflow:global_step/sec: 266.981
# INFO:tensorflow:loss = 79.836365, step = 1701 (0.375 sec)
# INFO:tensorflow:global_step/sec: 264.811
# INFO:tensorflow:loss = 18.375916, step = 1801 (0.382 sec)
# INFO:tensorflow:global_step/sec: 248.843
# INFO:tensorflow:loss = 113.52487, step = 1901 (0.400 sec)
# INFO:tensorflow:global_step/sec: 231.337
# INFO:tensorflow:loss = 75.259026, step = 2001 (0.436 sec)
# INFO:tensorflow:global_step/sec: 249.179
# INFO:tensorflow:loss = 60.930935, step = 2101 (0.399 sec)
# INFO:tensorflow:global_step/sec: 258.196
# INFO:tensorflow:loss = 42.938995, step = 2201 (0.384 sec)
# INFO:tensorflow:global_step/sec: 249.235
# INFO:tensorflow:loss = 30.107254, step = 2301 (0.406 sec)
# INFO:tensorflow:global_step/sec: 240.778
# INFO:tensorflow:loss = 62.038387, step = 2401 (0.411 sec)
# INFO:tensorflow:global_step/sec: 252.204
# INFO:tensorflow:loss = 59.804726, step = 2501 (0.395 sec)
# INFO:tensorflow:global_step/sec: 256.123
# INFO:tensorflow:loss = 45.207664, step = 2601 (0.395 sec)
# INFO:tensorflow:global_step/sec: 250.207
# INFO:tensorflow:loss = 30.061813, step = 2701 (0.400 sec)
# INFO:tensorflow:global_step/sec: 252.334
# INFO:tensorflow:loss = 23.890713, step = 2801 (0.394 sec)
# INFO:tensorflow:global_step/sec: 253.825
# INFO:tensorflow:loss = 65.8997, step = 2901 (0.395 sec)
# INFO:tensorflow:global_step/sec: 255.045
# INFO:tensorflow:loss = 68.25279, step = 3001 (0.393 sec)
# INFO:tensorflow:global_step/sec: 256.146
# INFO:tensorflow:loss = 58.2647, step = 3101 (0.390 sec)
# INFO:tensorflow:global_step/sec: 239.426
# INFO:tensorflow:loss = 31.986618, step = 3201 (0.421 sec)
# INFO:tensorflow:global_step/sec: 256.52
# INFO:tensorflow:loss = 24.190699, step = 3301 (0.385 sec)
# INFO:tensorflow:global_step/sec: 256.709
# INFO:tensorflow:loss = 90.46658, step = 3401 (0.395 sec)
# INFO:tensorflow:global_step/sec: 256.709
# INFO:tensorflow:loss = 78.97052, step = 3501 (0.389 sec)
# INFO:tensorflow:global_step/sec: 252.546
# INFO:tensorflow:loss = 74.75032, step = 3601 (0.394 sec)
# INFO:tensorflow:global_step/sec: 242.522
# INFO:tensorflow:loss = 46.76292, step = 3701 (0.409 sec)
# INFO:tensorflow:global_step/sec: 243.89
# INFO:tensorflow:loss = 92.245636, step = 3801 (0.410 sec)
# INFO:tensorflow:global_step/sec: 261.982
# INFO:tensorflow:loss = 45.23872, step = 3901 (0.385 sec)
# INFO:tensorflow:global_step/sec: 248.079
# INFO:tensorflow:loss = 39.092533, step = 4001 (0.405 sec)
# INFO:tensorflow:global_step/sec: 248.65
# INFO:tensorflow:loss = 38.681892, step = 4101 (0.396 sec)
# INFO:tensorflow:global_step/sec: 249.887
# INFO:tensorflow:loss = 23.653913, step = 4201 (0.402 sec)
# INFO:tensorflow:global_step/sec: 253.274
# INFO:tensorflow:loss = 50.580444, step = 4301 (0.393 sec)
# INFO:tensorflow:global_step/sec: 265.882
# INFO:tensorflow:loss = 44.73514, step = 4401 (0.380 sec)
# INFO:tensorflow:global_step/sec: 263.26
# INFO:tensorflow:loss = 30.1837, step = 4501 (0.378 sec)
# INFO:tensorflow:global_step/sec: 259.902
# INFO:tensorflow:loss = 42.775303, step = 4601 (0.382 sec)
# INFO:tensorflow:global_step/sec: 265.962
# INFO:tensorflow:loss = 28.421572, step = 4701 (0.377 sec)
# INFO:tensorflow:global_step/sec: 249.962
# INFO:tensorflow:loss = 36.474525, step = 4801 (0.400 sec)
# INFO:tensorflow:global_step/sec: 241.732
# INFO:tensorflow:loss = 93.416794, step = 4901 (0.417 sec)
# INFO:tensorflow:global_step/sec: 260.005
# INFO:tensorflow:loss = 57.909836, step = 5001 (0.383 sec)
# INFO:tensorflow:global_step/sec: 254.105
# INFO:tensorflow:loss = 73.78367, step = 5101 (0.393 sec)
# INFO:tensorflow:global_step/sec: 248.575
# INFO:tensorflow:loss = 27.45348, step = 5201 (0.407 sec)
# INFO:tensorflow:global_step/sec: 261.365
# INFO:tensorflow:loss = 65.80743, step = 5301 (0.383 sec)
# INFO:tensorflow:global_step/sec: 251.922
# INFO:tensorflow:loss = 51.903873, step = 5401 (0.391 sec)
# INFO:tensorflow:global_step/sec: 237.095
# INFO:tensorflow:loss = 49.47797, step = 5501 (0.421 sec)
# INFO:tensorflow:global_step/sec: 246.284
# INFO:tensorflow:loss = 46.949574, step = 5601 (0.406 sec)
# INFO:tensorflow:global_step/sec: 253.157
# INFO:tensorflow:loss = 31.345474, step = 5701 (0.396 sec)
# INFO:tensorflow:global_step/sec: 260.905
# INFO:tensorflow:loss = 58.411724, step = 5801 (0.382 sec)
# INFO:tensorflow:global_step/sec: 251.016
# INFO:tensorflow:loss = 56.01831, step = 5901 (0.405 sec)
# INFO:tensorflow:global_step/sec: 242.458
# INFO:tensorflow:loss = 41.67915, step = 6001 (0.407 sec)
# INFO:tensorflow:global_step/sec: 255.451
# INFO:tensorflow:loss = 39.067688, step = 6101 (0.395 sec)
# INFO:tensorflow:global_step/sec: 258.04
# INFO:tensorflow:loss = 31.657307, step = 6201 (0.385 sec)
# INFO:tensorflow:global_step/sec: 260.298
# INFO:tensorflow:loss = 43.460136, step = 6301 (0.385 sec)
# INFO:tensorflow:global_step/sec: 254.098
# INFO:tensorflow:loss = 76.3819, step = 6401 (0.395 sec)
# INFO:tensorflow:global_step/sec: 240.152
# INFO:tensorflow:loss = 45.70762, step = 6501 (0.417 sec)
# INFO:tensorflow:global_step/sec: 246.002
# INFO:tensorflow:loss = 31.077341, step = 6601 (0.402 sec)
# INFO:tensorflow:global_step/sec: 257.511
# INFO:tensorflow:loss = 28.125471, step = 6701 (0.388 sec)
# INFO:tensorflow:global_step/sec: 257.356
# INFO:tensorflow:loss = 63.020123, step = 6801 (0.389 sec)
# INFO:tensorflow:global_step/sec: 255.02
# INFO:tensorflow:loss = 52.062893, step = 6901 (0.393 sec)
# INFO:tensorflow:global_step/sec: 259.407
# INFO:tensorflow:loss = 89.48213, step = 7001 (0.389 sec)
# INFO:tensorflow:global_step/sec: 250.069
# INFO:tensorflow:loss = 21.076498, step = 7101 (0.399 sec)
# INFO:tensorflow:global_step/sec: 246.77
# INFO:tensorflow:loss = 62.340683, step = 7201 (0.406 sec)
# INFO:tensorflow:global_step/sec: 239.671
# INFO:tensorflow:loss = 31.83053, step = 7301 (0.415 sec)
# INFO:tensorflow:global_step/sec: 246.582
# INFO:tensorflow:loss = 57.256226, step = 7401 (0.407 sec)
# INFO:tensorflow:global_step/sec: 264.604
# INFO:tensorflow:loss = 50.002655, step = 7501 (0.378 sec)
# INFO:tensorflow:global_step/sec: 243.348
# INFO:tensorflow:loss = 38.61265, step = 7601 (0.406 sec)
# INFO:tensorflow:global_step/sec: 259.749
# INFO:tensorflow:loss = 55.025986, step = 7701 (0.388 sec)
# INFO:tensorflow:global_step/sec: 243.234
# INFO:tensorflow:loss = 42.19791, step = 7801 (0.409 sec)
# INFO:tensorflow:global_step/sec: 248.82
# INFO:tensorflow:loss = 65.22424, step = 7901 (0.406 sec)
# INFO:tensorflow:global_step/sec: 258.18
# INFO:tensorflow:loss = 41.27901, step = 8001 (0.387 sec)
# INFO:tensorflow:global_step/sec: 238.064
# INFO:tensorflow:loss = 35.3902, step = 8101 (0.416 sec)
# INFO:tensorflow:global_step/sec: 262.529
# INFO:tensorflow:loss = 38.341873, step = 8201 (0.381 sec)
# INFO:tensorflow:global_step/sec: 254.273
# INFO:tensorflow:loss = 78.5002, step = 8301 (0.398 sec)
# INFO:tensorflow:global_step/sec: 250.717
# INFO:tensorflow:loss = 44.66353, step = 8401 (0.399 sec)
# INFO:tensorflow:global_step/sec: 255.263
# INFO:tensorflow:loss = 47.04899, step = 8501 (0.391 sec)
# INFO:tensorflow:global_step/sec: 256.728
# INFO:tensorflow:loss = 41.059563, step = 8601 (0.386 sec)
# INFO:tensorflow:global_step/sec: 246.78
# INFO:tensorflow:loss = 69.34807, step = 8701 (0.407 sec)
# INFO:tensorflow:global_step/sec: 258.335
# INFO:tensorflow:loss = 46.30969, step = 8801 (0.385 sec)
# INFO:tensorflow:global_step/sec: 249.413
# INFO:tensorflow:loss = 61.850357, step = 8901 (0.407 sec)
# INFO:tensorflow:global_step/sec: 257.291
# INFO:tensorflow:loss = 32.908222, step = 9001 (0.383 sec)
# INFO:tensorflow:global_step/sec: 255.102
# INFO:tensorflow:loss = 22.339987, step = 9101 (0.392 sec)
# INFO:tensorflow:global_step/sec: 253.66
# INFO:tensorflow:loss = 74.29901, step = 9201 (0.398 sec)
# INFO:tensorflow:global_step/sec: 258.356
# INFO:tensorflow:loss = 46.86197, step = 9301 (0.386 sec)
# INFO:tensorflow:global_step/sec: 249.534
# INFO:tensorflow:loss = 40.419918, step = 9401 (0.403 sec)
# INFO:tensorflow:global_step/sec: 251.111
# INFO:tensorflow:loss = 40.6288, step = 9501 (0.394 sec)
# INFO:tensorflow:global_step/sec: 261.325
# INFO:tensorflow:loss = 26.281174, step = 9601 (0.383 sec)
# INFO:tensorflow:global_step/sec: 259.156
# INFO:tensorflow:loss = 42.88963, step = 9701 (0.386 sec)
# INFO:tensorflow:global_step/sec: 264.01
# INFO:tensorflow:loss = 64.0507, step = 9801 (0.384 sec)
# INFO:tensorflow:global_step/sec: 258.59
# INFO:tensorflow:loss = 39.82405, step = 9901 (0.382 sec)
# INFO:tensorflow:global_step/sec: 254.74
# INFO:tensorflow:loss = 43.226788, step = 10001 (0.397 sec)
# INFO:tensorflow:global_step/sec: 251.157
# INFO:tensorflow:loss = 33.15537, step = 10101 (0.393 sec)
# INFO:tensorflow:global_step/sec: 257.477
# INFO:tensorflow:loss = 63.30098, step = 10201 (0.392 sec)
# INFO:tensorflow:global_step/sec: 240.224
# INFO:tensorflow:loss = 47.409824, step = 10301 (0.413 sec)
# INFO:tensorflow:global_step/sec: 261.774
# INFO:tensorflow:loss = 75.96761, step = 10401 (0.383 sec)
# INFO:tensorflow:global_step/sec: 236.66
# INFO:tensorflow:loss = 25.366152, step = 10501 (0.423 sec)
# INFO:tensorflow:global_step/sec: 236.921
# INFO:tensorflow:loss = 42.432003, step = 10601 (0.422 sec)
# INFO:tensorflow:global_step/sec: 261.775
# INFO:tensorflow:loss = 76.074646, step = 10701 (0.384 sec)
# INFO:tensorflow:global_step/sec: 267.508
# INFO:tensorflow:loss = 60.402668, step = 10801 (0.371 sec)
# INFO:tensorflow:global_step/sec: 260.028
# INFO:tensorflow:loss = 32.990356, step = 10901 (0.391 sec)
# INFO:tensorflow:global_step/sec: 261.798
# INFO:tensorflow:loss = 29.048592, step = 11001 (0.376 sec)
# INFO:tensorflow:global_step/sec: 237.662
# INFO:tensorflow:loss = 46.44632, step = 11101 (0.423 sec)
# INFO:tensorflow:global_step/sec: 258.377
# INFO:tensorflow:loss = 41.133995, step = 11201 (0.384 sec)
# INFO:tensorflow:global_step/sec: 255.242
# INFO:tensorflow:loss = 46.435104, step = 11301 (0.396 sec)
# INFO:tensorflow:global_step/sec: 261.799
# INFO:tensorflow:loss = 47.402782, step = 11401 (0.378 sec)
# INFO:tensorflow:global_step/sec: 257.691
# INFO:tensorflow:loss = 25.485516, step = 11501 (0.388 sec)
# INFO:tensorflow:global_step/sec: 257.071
# INFO:tensorflow:loss = 23.694096, step = 11601 (0.389 sec)
# INFO:tensorflow:global_step/sec: 251.615
# INFO:tensorflow:loss = 95.46845, step = 11701 (0.399 sec)
# INFO:tensorflow:global_step/sec: 258.469
# INFO:tensorflow:loss = 43.3963, step = 11801 (0.390 sec)
# INFO:tensorflow:global_step/sec: 247.457
# INFO:tensorflow:loss = 71.992714, step = 11901 (0.403 sec)
# INFO:tensorflow:global_step/sec: 255.139
# INFO:tensorflow:loss = 15.2065115, step = 12001 (0.388 sec)
# INFO:tensorflow:global_step/sec: 259.882
# INFO:tensorflow:loss = 89.97838, step = 12101 (0.392 sec)
# INFO:tensorflow:global_step/sec: 248.664
# INFO:tensorflow:loss = 46.26275, step = 12201 (0.395 sec)
# INFO:tensorflow:global_step/sec: 263.291
# INFO:tensorflow:loss = 58.63378, step = 12301 (0.383 sec)
# INFO:tensorflow:global_step/sec: 248.435
# INFO:tensorflow:loss = 44.711967, step = 12401 (0.402 sec)
# INFO:tensorflow:global_step/sec: 257.918
# INFO:tensorflow:loss = 23.45381, step = 12501 (0.386 sec)
# INFO:tensorflow:global_step/sec: 258.87
# INFO:tensorflow:loss = 43.88814, step = 12601 (0.390 sec)
# INFO:tensorflow:global_step/sec: 259.362
# INFO:tensorflow:loss = 46.627384, step = 12701 (0.384 sec)
# INFO:tensorflow:global_step/sec: 260.521
# INFO:tensorflow:loss = 40.787193, step = 12801 (0.381 sec)
# INFO:tensorflow:global_step/sec: 261.598
# INFO:tensorflow:loss = 29.873476, step = 12901 (0.386 sec)
# INFO:tensorflow:global_step/sec: 248.372
# INFO:tensorflow:loss = 39.537045, step = 13001 (0.399 sec)
# INFO:tensorflow:global_step/sec: 259.899
# INFO:tensorflow:loss = 47.18357, step = 13101 (0.386 sec)
# INFO:tensorflow:global_step/sec: 228.592
# INFO:tensorflow:loss = 71.125305, step = 13201 (0.435 sec)
# INFO:tensorflow:global_step/sec: 247.825
# INFO:tensorflow:loss = 42.376717, step = 13301 (0.405 sec)
# INFO:tensorflow:global_step/sec: 259.611
# INFO:tensorflow:loss = 25.435486, step = 13401 (0.385 sec)
# INFO:tensorflow:global_step/sec: 245.482
# INFO:tensorflow:loss = 31.204924, step = 13501 (0.410 sec)
# INFO:tensorflow:global_step/sec: 248.556
# INFO:tensorflow:loss = 60.806526, step = 13601 (0.400 sec)
# INFO:tensorflow:Saving checkpoints for 13601 into ./housing_trained/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-03T06:26:46Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./housing_trained/model.ckpt-13601
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-03-06:26:46
# INFO:tensorflow:Saving dict for global step 13601: average_loss = 0.3888353, global_step = 13601, label/mean = 2.0917346, loss = 1321.6512, prediction/mean = 2.0898714, rmse = 62356.656
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 13601: ./housing_trained/model.ckpt-13601
# INFO:tensorflow:Loss for final step: 60.806526.
